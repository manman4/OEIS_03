# %% [markdown]
# ## sequence_list.csvの作成

# %%
import subprocess

result = subprocess.run(["ruby", "create_list.rb"], capture_output=True, text=True)
print(result.stdout)  # Rubyスクリプトの標準出力を表示

# エラー出力を表示
print("STDOUT:", result.stdout)
print("STDERR:", result.stderr)
# Out:
# STDOUT:
# STDERR:

# %%
import pandas as pd

data_file = 'sequence_list.csv'

# %% [markdown]
# # フォルダ毎の数列の数

# %%
df = pd.read_csv(data_file)
df.columns = ['no', 'seq_no']
df = df[['seq_no']]
df['seq_no'] = df['seq_no'] // 1000
df
# Out:
#        seq_no
# 0         300
# 1         300
# 2         300
# 3         300
# 4         300
# ...       ...
# 10096     397
# 10097     397
# 10098     397
# 10099     397
# 10100     397
#
# [10101 rows x 1 columns]

# %%
# show_rangeの開始に注意
show_range = list(range(299, 399+1))
df.plot.hist(bins=show_range)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# ヒストグラムの度数分布表を作成
hist = pd.cut(df['seq_no'], bins=show_range).value_counts().sort_index()

# 度数分布表を表示（ただし、度数が0は除く）
print('度数分布表')

cnt = 0
for i in hist.index:
    cnt += 1
    if i.right % 10 == 0:
        print()
    print(f'{i.right} : {hist[i]}', end=', ')

print()
print(f'合計 : {cnt}')
# Out:
# 度数分布表
#
# 300 : 47, 301 : 30, 302 : 24, 303 : 73, 304 : 42, 305 : 59, 306 : 64, 307 : 70, 308 : 59, 309 : 80,
# 310 : 0, 311 : 0, 312 : 0, 313 : 0, 314 : 0, 315 : 0, 316 : 40, 317 : 21, 318 : 73, 319 : 83,
# 320 : 105, 321 : 156, 322 : 76, 323 : 31, 324 : 17, 325 : 14, 326 : 8, 327 : 34, 328 : 21, 329 : 11,
# 330 : 17, 331 : 26, 332 : 28, 333 : 60, 334 : 23, 335 : 26, 336 : 71, 337 : 31, 338 : 48, 339 : 58,
# 340 : 28, 341 : 56, 342 : 71, 343 : 83, 344 : 94, 345 : 52, 346 : 87, 347 : 64, 348 : 48, 349 : 139,
# 350 : 75, 351 : 138, 352 : 114, 353 : 101, 354 : 137, 355 : 165, 356 : 174, 357 : 154, 358 : 103, 359 : 94,
# 360 : 184, 361 : 144, 362 : 193, 363 : 246, 364 : 204, 365 : 244, 366 : 163, 367 : 206, 368 : 175, 369 : 160,
# 370 : 189, 371 : 265, 372 : 191, 373 : 183, 374 : 81, 375 : 208, 376 : 145, 377 : 210, 378 : 106, 379 : 144,
# 380 : 156, 381 : 237, 382 : 167, 383 : 192, 384 : 192, 385 : 197, 386 : 160, 387 : 245, 388 : 54, 389 : 153,
# 390 : 239, 391 : 207, 392 : 196, 393 : 69, 394 : 104, 395 : 126, 396 : 105, 397 : 58, 398 : 0, 399 : 0,
# 合計 : 100

# %% [markdown]
# # 偏り

# %%
df = pd.read_csv(data_file)
df.columns = ['no', 'seq_no']
df = df[['seq_no']]
df['seq_no'] = df['seq_no'] % 100
df
# Out:
#        seq_no
# 0          11
# 1          25
# 2          48
# 3          52
# 4          53
# ...       ...
# 10096      68
# 10097      69
# 10098      70
# 10099      71
# 10100      33
#
# [10101 rows x 1 columns]

# %%
df.plot.hist(bins=100)
# Out:
# <Axes: ylabel='Frequency'>
